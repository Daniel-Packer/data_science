# %% [markdown]
# # Imports

# %%
from importlib import reload
import functions as f

# for data handling
import pandas as pd
import numpy as np

# for plotting
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("white")

# %%
# General

from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2,stratify=y)
from sklearn.model_selection import StratifiedKFold
from sklearn.base import clone
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures

# %%
# Regression

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
# Ridge(alpha=a, normalize=True)
from sklearn.linear_model import Lasso
# Lasso(alpha = alpha[i], normalize=True, max_iter = 1000000)
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
# Classification

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
# tree_clf = DecisionTreeClassifier(max_depth = 3)
# fig = tree_clf.fit(X, y)
# tree.plot_tree(fig,filled = True)
# plt.show()
# tree_clf.predict_proba(X)
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import plot_tree

from sklearn.svm import LinearSVC # LinearSVC(C=1, loss="hinge")
from sklearn.svm import SVC

from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.neighbors import KNeighborsClassifier
# neigh = KNeighborsClassifier(n_neighbors=5)
# neigh.fit(X,y)

# %%
# Unsupervised learning

from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.cluster import AgglomerativeClustering

from sklearn.decomposition import PCA
# pca = PCA(n_components=10)
# pca.explained_variance_ratio_
# plt.matshow(pca_pipe['pca'].components_, cmap = 'plasma')

from sklearn.manifold import MDS
# mds = MDS(n_components = 2)
# X_mds = mds.fit_transform(X)

from sklearn.manifold import LocallyLinearEmbedding
# lle = LocallyLinearEmbedding(n_neighbors=100, n_components=2, method='modified', eigen_solver='dense')
# X_lle = lle.fit_transform(X)

from sklearn.manifold import Isomap
# iso = Isomap(n_neighbors=160, n_components=2)
# X_iso = iso.fit_transform(X)

from sklearn.manifold import TSNE
# tsne = TSNE(n_components = 2, perplexity=50)
# X_tsne = tsne.fit_transform(X)

# %%
# For reloading our functions library if anything is changed
f = reload(f)

# %% [markdown]
# # Work

# %% [markdown]
# ## Time

# %% [markdown]
# Checking these are all blitz-like

# %%
import json

game_dicts = json.load(open('rosen_russian.json'))

# %%
times = [game_dict['time_control'] for game_dict in game_dicts]

# %%
set(times)
# Out:
# {'180+0',
#  '180+2',
#  '180+3',
#  '180+5',
#  '240+0',
#  '240+2',
#  '300+0',
#  '300+1',
#  '300+2',
#  '300+3',
#  '300+4',
#  '420+1'}

# %% [markdown]
# ## Importing Data

# %%
df = pd.read_csv('rosen_russian.csv')
df_copy = df.copy()

# %%
# Simplify the white player labels
for i in range(len(df_copy)):
    name = df_copy['white_player'].at[i]
    if name == 'EricRosen':
        df_copy['white_player'].at[i] = 'Rosen'
    elif name == 'RussianBlizzard':
        df_copy['white_player'].at[i] = 'Russian'
    else:
        df_copy['white_player'].at[i] = 'Other'

# %%
df_copy.sample(10)
# Out:
#                            game_id white_player  wn_pair  wn_outpost  \
# 814   https://lichess.org/7MO9C6zK        Other        0       0.000
# 1213  https://lichess.org/BNGvNoRy      Russian        0       0.000
# 1795  https://lichess.org/JiVn1Dec        Other        0       0.000
# 579   https://lichess.org/0elLvrOl        Rosen        0       0.000
# 203   https://lichess.org/tWMNsjSQ        Other        0       0.125
# 1324  https://lichess.org/gnRyGw7N      Russian        0       0.000
# 1349  https://lichess.org/5saatwQ9        Other        0       0.000
# 723   https://lichess.org/3VO8Vfjy        Rosen        0       0.000
# 1816  https://lichess.org/Tek8IiVg      Russian        0       0.000
# 1242  https://lichess.org/73pDKW8m        Other        0       0.000
#
#       wn_repositioning  wn_mobility  wb_pair  wk_side_fianchetto  \
# 814           0.000000     3.105263        0                   0
# 1213          0.000000     0.375000        0                   0
# 1795          0.036806     2.875000        0                   0
# 579           0.007819     0.000000        1                   1
# 203           0.059669     2.125000        0                   0
# 1324          0.130709     2.062500        0                   0
# 1349          0.071519     1.343750        0                   0
# 723           0.011905     3.214286        0                   0
# 1816          0.360777     0.961538        1                   0
# 1242          0.000000     2.750000        0                   0
#
#       wq_side_fianchetto  wb_mobility  ...  num_direct_trades  \
# 814                    0     3.631579  ...                  2
# 1213                   0     2.562500  ...                  2
# 1795                   0     3.900000  ...                  7
# 579                    0     2.759259  ...                  6
# 203                    0     2.687500  ...                  5
# 1324                   1     2.484375  ...                  3
# 1349                   0     2.234375  ...                  1
# 723                    0     3.107143  ...                  2
# 1816                   1     3.000000  ...                  7
# 1242                   0     3.078125  ...                  6
#
#       num_indirect_trades  num_direct_trades_white  num_indirect_trades_white  \
# 814                     0                        0                          0
# 1213                    0                        1                          0
# 1795                    0                        6                          0
# 579                     0                        1                          0
# 203                     0                        1                          0
# 1324                    0                        3                          0
# 1349                    1                        1                          1
# 723                     0                        1                          0
# 1816                    0                        4                          0
# 1242                    0                        3                          0
#
#       avg_time_between_direct_trade  exchanges_possible  \
# 814                             1.5            0.375000
# 1213                            1.0            0.150000
# 1795                            1.0            0.833333
# 579                             1.2            0.680000
# 203                             1.5            0.761905
# 1324                            0.0            0.280000
# 1349                            0.0            0.518519
# 723                             1.0            0.562500
# 1816                            1.0            0.481481
# 1242                            1.0            0.400000
#
#       king_squares_attacked  king_moves  king_moves_weighted  \
# 814                1.210526           1                   38
# 1213               0.062500           0                    0
# 1795               0.000000           0                    0
# 579                0.629630           1                   21
# 203                1.000000           0                    0
# 1324               0.343750           1                   37
# 1349               0.062500           0                    0
# 723                0.000000           0                    0
# 1816               0.000000           0                    0
# 1242               0.343750           0                    0
#
#       distance_from_king
# 814             3.538662
# 1213            3.583288
# 1795            3.504067
# 579             3.651400
# 203             3.382900
# 1324            3.288177
# 1349            3.274295
# 723             3.499686
# 1816            3.343125
# 1242            3.478720
#
# [10 rows x 95 columns]

# %%
# Remove the 'Other' ones
df_copy = df_copy[df_copy['white_player'] != 'Other']
df_copy.sample(10)
# Out:
#                            game_id white_player  wn_pair  wn_outpost  \
# 352   https://lichess.org/xnX1LuqD        Rosen        0    0.000000
# 1906  https://lichess.org/Rml0s2sx      Russian        0    0.000000
# 395   https://lichess.org/9QXQOUcf        Rosen        0    0.000000
# 782   https://lichess.org/P3VOl7RY        Rosen        0    0.000000
# 1407  https://lichess.org/ejK3f5Wa      Russian        0    0.000000
# 1212  https://lichess.org/tQsnXg5G      Russian        0    0.000000
# 533   https://lichess.org/aAdaUqMx        Rosen        0    0.000000
# 1813  https://lichess.org/fDYzfiNQ      Russian        0    0.000000
# 1387  https://lichess.org/gczbguWn      Russian        0    0.000000
# 633   https://lichess.org/kJIRB2oW        Rosen        0    0.043478
#
#       wn_repositioning  wn_mobility  wb_pair  wk_side_fianchetto  \
# 352           0.168199     1.428571        1                   0
# 1906          0.064749     2.521739        0                   0
# 395           0.030788     1.413793        0                   0
# 782           0.110227     2.177778        0                   0
# 1407          0.047287     0.000000        1                   0
# 1212          0.011668     1.233333        0                   0
# 533           0.000000     0.000000        1                   0
# 1813          0.056266     2.500000        1                   0
# 1387          0.000000     0.000000        0                   0
# 633           0.098602     0.260870        0                   1
#
#       wq_side_fianchetto  wb_mobility  ...  num_direct_trades  \
# 352                    0     2.523810  ...                  6
# 1906                   1     1.608696  ...                  7
# 395                    0     4.724138  ...                  5
# 782                    0     2.866667  ...                  6
# 1407                   1     2.483871  ...                  5
# 1212                   1     3.566667  ...                  6
# 533                    0     2.500000  ...                  3
# 1813                   1     1.708333  ...                  4
# 1387                   0     0.000000  ...                  3
# 633                    0     0.434783  ...                  2
#
#       num_indirect_trades  num_direct_trades_white  num_indirect_trades_white  \
# 352                     1                        4                          0
# 1906                    1                        3                          1
# 395                     0                        2                          0
# 782                     0                        1                          0
# 1407                    1                        1                          0
# 1212                    0                        3                          0
# 533                     0                        1                          0
# 1813                    0                        4                          0
# 1387                    0                        0                          0
# 633                     1                        0                          0
#
#       avg_time_between_direct_trade  exchanges_possible  \
# 352                        1.000000            0.869565
# 1906                       1.000000            0.464286
# 395                        1.000000            0.217391
# 782                        1.400000            0.266667
# 1407                       1.000000            0.928571
# 1212                       1.000000            0.333333
# 533                        1.000000            0.416667
# 1813                       0.000000            0.440000
# 1387                       1.333333            0.857143
# 633                        1.500000            0.307692
#
#       king_squares_attacked  king_moves  king_moves_weighted  \
# 352                0.333333           1                   39
# 1906               0.391304           1                   27
# 395                0.000000           0                    0
# 782                0.400000           1                   21
# 1407               0.935484           2                   61
# 1212               0.000000           0                    0
# 533                0.714286           0                    0
# 1813               0.166667           0                    0
# 1387               0.000000           0                    0
# 633                0.217391           0                    0
#
#       distance_from_king
# 352             3.374373
# 1906            3.292486
# 395             3.631165
# 782             3.450248
# 1407            3.426908
# 1212            3.615206
# 533             3.379538
# 1813            3.494277
# 1387            3.518849
# 633             3.420183
#
# [10 rows x 95 columns]

# %%
# Make the data and features, train/test split
X = df_copy.drop(columns = ['game_id','white_player'])
y = df_copy['white_player']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2,stratify=y)
X_train.head()
# Out:
#       wn_pair  wn_outpost  wn_repositioning  wn_mobility  wb_pair  \
# 277         0    0.040816          0.279983     2.387755        0
# 1244        0    0.000000          0.165581     1.709677        0
# 685         0    0.000000          0.000000     1.583333        0
# 387         0    0.000000          0.132691     2.391304        0
# 76          0    0.030303          0.241480     1.030303        0
#
#       wk_side_fianchetto  wq_side_fianchetto  wb_mobility  \
# 277                    0                   0     2.112245
# 1244                   0                   1     1.096774
# 685                    0                   0     3.500000
# 387                    0                   0     2.391304
# 76                     0                   0     2.606061
#
#       wlong_diagonal_control  wopposite_color_b  ...  num_direct_trades  \
# 277                 0.510204                 -1  ...                  4
# 1244                0.645161                 -1  ...                  6
# 685                 0.000000                  1  ...                  5
# 387                 0.000000                  0  ...                  2
# 76                  0.000000                 -1  ...                  5
#
#       num_indirect_trades  num_direct_trades_white  num_indirect_trades_white  \
# 277                     0                        3                          0
# 1244                    0                        2                          0
# 685                     1                        4                          0
# 387                     0                        2                          0
# 76                      0                        3                          0
#
#       avg_time_between_direct_trade  exchanges_possible  \
# 277                             1.0            0.888889
# 1244                            1.0            0.636364
# 685                             1.0            0.388889
# 387                             0.0            0.652174
# 76                              1.0            0.575758
#
#       king_squares_attacked  king_moves  king_moves_weighted  \
# 277                0.020408           1                   29
# 1244               0.322581           1                   34
# 685                1.083333           0                    0
# 387                0.130435           1                   38
# 76                 2.303030           1                   39
#
#       distance_from_king
# 277             3.220793
# 1244            3.153783
# 685             3.507614
# 387             3.400342
# 76              2.973355
#
# [5 rows x 93 columns]

# %%
y_train.head()
# Out:
# 1688    Russian
# 808       Rosen
# 1669    Russian
# 88        Rosen
# 1068    Russian
# Name: white_player, dtype: object

# %% [markdown]
# ## Dimensionality reduction

# %% [markdown]
# ### PCA

# %%
n = 50
pca_pipe = Pipeline([('scale',StandardScaler()), ('pca',PCA(n_components = n))])
X_train_pipe = pca_pipe.fit_transform(X_train,y_train)

# %%
plt.plot(np.arange(1,n+1),np.cumsum(pca_pipe['pca'].explained_variance_ratio_))

# %%
plt.matshow(pca_pipe['pca'].components_, cmap = 'plasma')
plt.show()

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Nearest Neighbors

# %%
neigh_pipe = Pipeline([('scaler',StandardScaler()),('neigh',KNeighborsClassifier(n_neighbors = 9))])
neigh_pipe.fit(X_train,y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('scaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('neigh',
#                  KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                       metric='minkowski', metric_params=None,
#                                       n_jobs=None, n_neighbors=9, p=2,
#                                       weights='uniform'))],
#          verbose=False)

# %%
pred = neigh_pipe.predict(X_test)

# %%
sum(pred==y_test)/len(y_test)
# Out:
# 0.8795811518324608

# %% [markdown]
# ### Decision Tree

# %%
tree_clf = DecisionTreeClassifier(max_depth = 3)
fig, ax = plt.subplots(figsize=(10, 10))
fig = tree_clf.fit(X_train, y_train)
tree.plot_tree(fig,filled = True,ax=ax)
plt.show()

# %%
pred = tree_clf.predict(X_test)
sum(pred==y_test)/len(y_test)
# Out:
# 0.8952879581151832

# %%
[X.columns[i] for i in [5,29,33,16,34,24,23]]
# Out:
# ['wk_side_fianchetto',
#  'B#',
#  'w_development_side',
#  'wdoubled_r',
#  'wc_earliness',
#  'B',
#  'A']

# %% [markdown]
# So the decision tree is finding that the opening is pretty important for prediction

# %% [markdown]
# ### Custom: by opening

# %% [markdown]
# For each opening type (A,B,C,D,E) I'll classify it as Rosen or Russian (based on who did that opening the most often). Then check how predictive that is.

# %%
rosen_openings = [0,0,0,0,0]
rosen_train = X_train.loc[y_train == 'Rosen']
rosen_openings[0] = sum(rosen_train['A'] == 1) / len(rosen_train)
rosen_openings[1] = sum(rosen_train['B'] == 1) / len(rosen_train)
rosen_openings[2] = sum(rosen_train['C'] == 1) / len(rosen_train)
rosen_openings[3] = sum(rosen_train['D'] == 1) / len(rosen_train)
rosen_openings[3] = sum(rosen_train['E'] == 1) / len(rosen_train)
rosen_openings
# Out:
# [0.37606837606837606,
#  0.2905982905982906,
#  0.1623931623931624,
#  0.005698005698005698,
#  0]

# %%
russian_openings = [0,0,0,0,0]
russian_train = X_train.loc[y_train == 'Russian']
russian_openings[0] = sum(russian_train['A'] == 1) / len(russian_train)
russian_openings[1] = sum(russian_train['B'] == 1) / len(russian_train)
russian_openings[2] = sum(russian_train['C'] == 1) / len(russian_train)
russian_openings[3] = sum(russian_train['D'] == 1) / len(russian_train)
russian_openings[3] = sum(russian_train['E'] == 1) / len(russian_train)
russian_openings
# Out:
# [0.012195121951219513,
#  0.6829268292682927,
#  0.3024390243902439,
#  0.0024390243902439024,
#  0]

# %%
opening_pred = ['','','','','']
for i in range(5):
    if rosen_openings[i] > russian_openings[i]:
        opening_pred[i] = 'Rosen'
    else:
        opening_pred[i] = 'Russian'
opening_pred
# Out:
# ['Rosen', 'Russian', 'Russian', 'Rosen', 'Russian']

# %%
pred = y_test.copy()
for i in range(len(X_test)):
    openings = list(X_test[['A','B','C','D','E']].iloc[i])
    opening_index = np.argmax(openings)
    pred.iloc[i] = opening_pred[opening_index]

# %%
pred
# Out:
# 1298    Russian
# 372       Rosen
# 440       Rosen
# 1676    Russian
# 1308    Russian
#          ...
# 1397    Russian
# 1873    Russian
# 1190    Russian
# 1788    Russian
# 827     Russian
# Name: white_player, Length: 191, dtype: object

# %%
sum(pred==y_test)/len(y_test)
# Out:
# 0.7905759162303665

# %%
import sklearn

guesses = pred
actual = y_test

labels = ['Rosen','Russian']

c_matrix = np.round(sklearn.metrics.confusion_matrix(actual,guesses,labels = labels) / len(y_test),2)

# %%
fig, ax = plt.subplots()
im = ax.imshow(c_matrix)

# We want to show all ticks...
ax.set_xticks(np.arange(len(labels)))
ax.set_yticks(np.arange(len(labels)))
# ... and label them with the respective list entries
ax.set_xticklabels(labels)
ax.set_yticklabels(labels)

# Axes labels
plt.ylabel('Actual')
plt.xlabel('Predicted')

# Loop over data dimensions and create text annotations.
for i in range(len(labels)):
    for j in range(len(labels)):
        text = ax.text(j, i, c_matrix[i, j],
                       ha="center", va="center", color="w")

fig.colorbar(im)
        
ax.set_title("Confusion matrix")
fig.tight_layout()
plt.show()

# %% [markdown]
# # Stratifying by opening
#
# Given how well the opening predicted the player, let's try improving that by training data of a single classifier on each separate opening.
#
# Matt said it's better not to do this I think, bc we wanna limit the number of separate classifiers we train. But fuck it, let's see if it works first.
#
# Need to
# - See how many of each type of opening there are, i.e. do we have enough data to stratify
# - Try it on one opening first, and compare with the naive prediction from the pure-opening classifier
#
# Maybe with train_test_split we can do this stratifying at the start

# %%
letters = ['A','B','C','D','E']
stratified = [df_copy[df_copy[letter] == 1] for letter in letters]

# %%
[len(letter_data) for letter_data in stratified]
# Out:
# [170, 467, 237, 73, 5]

# %%
len(df_copy)
# Out:
# 952

# %%
[[len(letter_data[letter_data['white_player'] == 'Rosen']),len(letter_data[letter_data['white_player'] == 'Russian'])] for letter_data in stratified]
# Out:
# [[165, 5], [120, 347], [77, 160], [73, 0], [4, 1]]

# %% [markdown]
# I'll train it on the B data, I'm trying to beat the naive:

# %%
347/(347+120)
# Out:
# 0.7430406852248393

# %%
B_df = stratified[1]
B_df.head()
# Out:
#                          game_id white_player  wn_pair  wn_outpost  \
# 2   https://lichess.org/5eppQZDZ        Rosen        0    0.428571
# 3   https://lichess.org/L9DC3KN3        Rosen        0    0.000000
# 12  https://lichess.org/zmgap7Xk        Rosen        0    0.029412
# 13  https://lichess.org/TksYEEUz        Rosen        0    0.173913
# 39  https://lichess.org/sESYcNRo        Rosen        0    0.315789
#
#     wn_repositioning  wn_mobility  wb_pair  wk_side_fianchetto  \
# 2           0.470635     1.628571        0                   0
# 3           0.046737     3.692308        0                   0
# 12          0.660155     2.088235        0                   0
# 13          0.265878     3.413043        0                   0
# 39          0.341689     1.578947        0                   1
#
#     wq_side_fianchetto  wb_mobility  ...  num_direct_trades  \
# 2                    0     3.542857  ...                  5
# 3                    0     1.846154  ...                  3
# 12                   0     3.852941  ...                  5
# 13                   0     2.695652  ...                  4
# 39                   0     1.973684  ...                  5
#
#     num_indirect_trades  num_direct_trades_white  num_indirect_trades_white  \
# 2                     0                        3                          0
# 3                     0                        1                          0
# 12                    1                        2                          0
# 13                    0                        2                          0
# 39                    1                        1                          1
#
#     avg_time_between_direct_trade  exchanges_possible  king_squares_attacked  \
# 2                             1.5            0.535714               0.657143
# 3                             1.0            0.571429               0.000000
# 12                            1.0            0.480000               0.382353
# 13                            1.0            0.750000               0.217391
# 39                            1.5            0.411765               0.894737
#
#     king_moves  king_moves_weighted  distance_from_king
# 2            0                    0            3.555586
# 3            0                    0            3.516140
# 12           0                    0            3.250023
# 13           1                   36            3.607861
# 39           1                   20            3.445705
#
# [5 rows x 95 columns]

# %%
# The opening columns give us no info, remove all but A#
X_B = B_df.drop(columns = ['game_id','white_player','A','B','C','D','E','B#','C#','D#','E#'])
y_B = B_df['white_player']
X_B_train, X_B_test, y_B_train, y_B_test = train_test_split(X_B,y_B,test_size = 0.2,stratify=y_B)

# %%
len(X_B_train)
# Out:
# 373

# %% [markdown]
# ### PCA

# %%
n = 50
pca_pipe = Pipeline([('scale',StandardScaler()), ('pca',PCA(n_components = n))])
X_B_train_pipe = pca_pipe.fit_transform(X_B_train,y_B_train)

# %%
plt.plot(np.arange(1,n+1),np.cumsum(pca_pipe['pca'].explained_variance_ratio_))

# %%
plt.matshow(pca_pipe['pca'].components_, cmap = 'plasma')
plt.colorbar()
plt.show()

# %% [markdown]
# ### K nearest neighbors

# %%
neigh_pipe = Pipeline([('scaler',StandardScaler()),('neigh',KNeighborsClassifier(n_neighbors = 5))])
neigh_pipe.fit(X_B_train,y_B_train)
# Out:
# Pipeline(memory=None,
#          steps=[('scaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('neigh',
#                  KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                       metric='minkowski', metric_params=None,
#                                       n_jobs=None, n_neighbors=5, p=2,
#                                       weights='uniform'))],
#          verbose=False)

# %%
pred = neigh_pipe.predict(X_B_test)
sum(pred==y_B_test)/len(y_B_test)
# Out:
# 0.8191489361702128

# %% [markdown]
# It beats the naive 74% classification!

# %% [markdown]
# ### Decision tree

# %%
tree_clf = DecisionTreeClassifier(max_depth = 3)
fig, ax = plt.subplots(figsize=(10, 10))
fig = tree_clf.fit(X_B_train, y_B_train)
tree.plot_tree(fig,filled = True,ax=ax)
plt.show()

# %%
[X_B.columns[i] for i in [6,25,35,24,19]]
# Out:
# ['wq_side_fianchetto',
#  'wc_earliness',
#  'wp_tension',
#  'w_development_side',
#  'wq_aggression']

# %%
pred = tree_clf.predict(X_B_test)
sum(pred==y_B_test)/len(y_B_test)
# Out:
# 0.7978723404255319

# %%
B_num_rosen = X_B[y_B == 'Rosen']['wq_side_fianchetto']
B_num_russian = X_B[y_B == 'Russian']['wq_side_fianchetto']

# %%
plt.hist([B_num_rosen,B_num_russian],bins = 20, density = True)
plt.show()

# %% [markdown]
# The Russian likes to queen fianchetto lol

# %% [markdown]
# ### Random forest

# %%
forest_clf = RandomForestClassifier(max_depth = 4)
forest_clf.fit(X_B_train,y_B_train)
pred = forest_clf.predict(X_B_test)
sum(pred == y_B_test)/len(y_B_test)
# Out:
# 0.8085106382978723

# %%
names = []
scores = []
for name, score in zip(X_B_train.columns,forest_clf.feature_importances_):
    names.append(name)
    scores.append(np.round(score,4))
    
score_df = pd.DataFrame({'feature':names,'importance_score':scores})

score_df = score_df.sort_values('importance_score',ascending=False)

# %%
score_df.head(20)
# Out:
#                feature  importance_score
# 23                  A#            0.1246
# 5   wk_side_fianchetto            0.0515
# 47           wb_attack            0.0367
# 22         wq_mobility            0.0358
# 55              wcl_MR            0.0337
# 12   wn_b_develop_pref            0.0335
# 46          wb_density            0.0323
# 34         wp_backward            0.0248
# 31  wp_center_strength            0.0242
# 57              wcl_BL            0.0241
# 79  exchanges_possible            0.0233
# 25        wc_earliness            0.0230
# 63             P_moves            0.0193
# 24  w_development_side            0.0183
# 19       wq_aggression            0.0166
# 69          pins_given            0.0159
# 67             Q_moves            0.0159
# 44             wb_rank            0.0157
# 48        wb_pawn_pref            0.0157
# 3          wn_mobility            0.0153

# %% [markdown]
# Some similarities to the regular decision tree's features

# %% [markdown]
# ### Let's try SVC

# %%
svc_pipe = Pipeline([('scaler', StandardScaler()),('svc', SVC(kernel = "rbf", C=1))])
svc_pipe.fit(X_B_train,y_B_train)
# Out:
# Pipeline(memory=None,
#          steps=[('scaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('svc',
#                  SVC(C=1, break_ties=False, cache_size=200, class_weight=None,
#                      coef0=0.0, decision_function_shape='ovr', degree=3,
#                      gamma='scale', kernel='rbf', max_iter=-1,
#                      probability=False, random_state=None, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
pred = svc_pipe.predict(X_B_test)
sum(pred == y_B_test)/len(y_B_test)
# Out:
# 0.8829787234042553

# %% [markdown]
# ## Unsupervised stuff

# %%
pca_pipe = Pipeline([('scaler',StandardScaler()),('pca',PCA(n_components = 2))])
transform = pca_pipe.fit_transform(X_B)

indices = y_B == 'Rosen'
plt.scatter(transform[indices][:,0],transform[indices][:,1],label='Rosen')
indices = y_B == 'Russian'
plt.scatter(transform[indices][:,0],transform[indices][:,1],label='Russian')
plt.legend()
plt.show()

# %%
pipe = Pipeline([('scaler',StandardScaler()),('mds',MDS(n_components = 2))])
transform = pipe.fit_transform(X_B)

indices = y_B == 'Rosen'
plt.scatter(transform[indices][:,0],transform[indices][:,1],label='Rosen')
indices = y_B == 'Russian'
plt.scatter(transform[indices][:,0],transform[indices][:,1],label='Russian')
plt.legend()
plt.show()

# %%
pipe = Pipeline([('scaler',StandardScaler()),
                 ('lle',LocallyLinearEmbedding(n_neighbors=50, n_components=2, method='modified', eigen_solver='dense'))])
transform = pipe.fit_transform(X_B)

indices = y_B == 'Rosen'
plt.scatter(transform[indices][:,0],transform[indices][:,1],label='Rosen')
indices = y_B == 'Russian'
plt.scatter(transform[indices][:,0],transform[indices][:,1],label='Russian')
plt.legend()
plt.show()

# %%
pipe = Pipeline([('scaler',StandardScaler()),
                 ('iso',Isomap(n_neighbors=100, n_components=2))])
transform = pipe.fit_transform(X_B)

indices = y_B == 'Rosen'
plt.scatter(transform[indices][:,0],transform[indices][:,1],label='Rosen')
indices = y_B == 'Russian'
plt.scatter(transform[indices][:,0],transform[indices][:,1],label='Russian')
plt.legend()
plt.show()

# %%
pipe = Pipeline([('scaler',StandardScaler()),
                 ('tsne',TSNE(n_components = 2, perplexity=50))])
transform = pipe.fit_transform(X_B)

indices = y_B == 'Rosen'
plt.scatter(transform[indices][:,0],transform[indices][:,1],label='Rosen')
indices = y_B == 'Russian'
plt.scatter(transform[indices][:,0],transform[indices][:,1],label='Russian')
plt.legend()
plt.show()

# %% [markdown]
# PCA does pretty well with it

# %% [markdown]
# # PCA + Classifier?

# %%
pipe = Pipeline([('scaler',StandardScaler()),
                 ('pca',PCA(n_components = 10)),
                ('svc', SVC(kernel = "rbf", C=1))
                ])
pipe.fit(X_B_train,y_B_train)

pred = pipe.predict(X_B_test)
sum(pred==y_B_test)/len(y_B_test)
# Out:
# 0.776595744680851

# %% [markdown]
# # Stratified KNN
#
# New strat: make 5 KNN classifiers (one for each opening letter, probably drop the A#-E# thing), see how that goes

# %%
# Does this custom classification to a dataframe X
def predict(X):
    # Removing the opening info
    X_thin = X.drop(columns = ['A','B','C','D','E','A#','B#','C#','D#','E#'])
    
    pred = [''] * len(X)
    
    for i in range(len(X)):
        # Get the row we're looking at
        row = X.iloc[i]
        
        # Figure out the index of its opening
        index = -1
        for j in range(len(letters)):
            if row[letters[j]] == 1:
                index = j
                break
        
        # Code for doing the naive guess on E opening stuff, because there's only like 5 data points
        if index == -1:
            pred[i] = 'Rosen'
            continue
        
        # Remove the opening info
        row_thin = X_thin.iloc[i]
        
        # Run the classifier
        pred[i] = pipes[index].predict(row_thin.values.reshape(1,-1))[0]
    
    # Return the predictions
    return pred

# %%
n_neighbors = 5
letters = ['A','B','C','D']

# Create the 5 classifiers
pipes = [Pipeline([('scale',StandardScaler()),('knn',KNeighborsClassifier(n_neighbors = n_neighbors))]) for letter in letters]

# Stratify the training data
# Also making sure to remove info about the opening
X_train_thin = X_train.drop(columns = ['A','B','C','D','E','A#','B#','C#','D#','E#'])
X_train_stratified = [X_train_thin[X_train[letter] == 1] for letter in letters]
y_train_stratified = [y_train[X_train[letter] == 1] for letter in letters]

# Train the 5 classifiers
for i in range(len(letters)):
    pipes[i].fit(X_train_stratified[i],y_train_stratified[i])

# Predict
pred = predict(X_test)
sum(pred==y_test)/len(y_test)
# Out:
# 0.8952879581151832

# %%
letters = ['A','B','C','D']

# Create the 5 classifiers
pipes = [Pipeline([('scale',StandardScaler()),('rf',RandomForestClassifier(max_depth = 3))]) for letter in letters]

# Stratify the training data
# Also making sure to remove info about the opening
X_train_thin = X_train.drop(columns = ['A','B','C','D','E','A#','B#','C#','D#','E#'])
X_train_stratified = [X_train_thin[X_train[letter] == 1] for letter in letters]
y_train_stratified = [y_train[X_train[letter] == 1] for letter in letters]

# Train the 5 classifiers
for i in range(len(letters)):
    pipes[i].fit(X_train_stratified[i],y_train_stratified[i])

# Predict
pred = predict(X_test)
sum(pred==y_test)/len(y_test)
# Out:
# 0.9267015706806283

# %% [markdown]
# Pretty great. Now that I've run the same analysis as I did on Magnus-Nihal and showed it works better here, let's do some actual general classification.

# %% [markdown]
# # Actual Good Classification

# %%
# ('knn',KNeighborsClassifier(n_neighbors = 5))
# ('svc', SVC(kernel = "rbf", C=1))
pipe = Pipeline([('scaler',StandardScaler()),
                 ('pca',PCA(n_components = 10)),
                 ('svc', SVC(kernel = "rbf", C=1))
                ])
pipe.fit(X_train,y_train)

pred = pipe.predict(X_test)
sum(pred==y_test)/len(y_test)
# Out:
# 0.8691099476439791

# %%
import sklearn

guesses = pred
actual = y_test

labels = ['Rosen','Russian']

c_matrix = np.round(sklearn.metrics.confusion_matrix(actual,guesses,labels = labels) / len(y_test),2)

# %%
fig, ax = plt.subplots()
im = ax.imshow(c_matrix)

# We want to show all ticks...
ax.set_xticks(np.arange(len(labels)))
ax.set_yticks(np.arange(len(labels)))
# ... and label them with the respective list entries
ax.set_xticklabels(labels)
ax.set_yticklabels(labels)

# Axes labels
plt.ylabel('Actual')
plt.xlabel('Predicted')

# Loop over data dimensions and create text annotations.
for i in range(len(labels)):
    for j in range(len(labels)):
        text = ax.text(j, i, c_matrix[i, j],
                       ha="center", va="center", color="w")

fig.colorbar(im)
        
ax.set_title("Confusion matrix")
fig.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# This is ~15% better than the naive method (74% accurate) of guessing whichever IM does the opening the most often
#
# I'd say this is a win, let's bring in the whole data set and try to tell apart Rosen-Russian-Other

# %%
df = pd.read_csv('rosen_russian.csv')
df_copy = df.copy()

# %%
# Simplify the white player labels
for i in range(len(df_copy)):
    name = df_copy['white_player'].at[i]
    if name == 'EricRosen':
        df_copy['white_player'].at[i] = 'Rosen'
    elif name == 'RussianBlizzard':
        df_copy['white_player'].at[i] = 'Russian'
    else:
        df_copy['white_player'].at[i] = 'Other'

# %%
# Make the data and features, train/test split
X = df_copy.drop(columns = ['game_id','white_player'])
y = df_copy['white_player']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2,stratify=y)
X_train.head()
# Out:
#       wn_pair  wn_outpost  wn_repositioning  wn_mobility  wb_pair  \
# 1106        0         0.0          0.000000     2.076923        0
# 1463        0         0.0          0.040878     1.500000        0
# 1795        0         0.0          0.036806     2.875000        0
# 542         0         0.4          0.366516     2.100000        0
# 1656        0         0.0          0.224538     2.547619        0
#
#       wk_side_fianchetto  wq_side_fianchetto  wb_mobility  \
# 1106                   0                   1     1.153846
# 1463                   0                   0     2.562500
# 1795                   0                   0     3.900000
# 542                    0                   0     2.300000
# 1656                   0                   0     1.285714
#
#       wlong_diagonal_control  wopposite_color_b  ...  num_direct_trades  \
# 1106                0.923077                 -1  ...                  6
# 1463                0.000000                  0  ...                  4
# 1795                0.000000                 -1  ...                  7
# 542                 0.000000                  0  ...                  2
# 1656                0.857143                 -1  ...                  5
#
#       num_indirect_trades  num_direct_trades_white  num_indirect_trades_white  \
# 1106                    1                        2                          0
# 1463                    0                        3                          0
# 1795                    0                        6                          0
# 542                     0                        2                          0
# 1656                    0                        1                          0
#
#       avg_time_between_direct_trade  exchanges_possible  \
# 1106                            1.0            0.550000
# 1463                            3.0            0.357143
# 1795                            1.0            0.833333
# 542                             0.0            0.391304
# 1656                            1.0            0.440000
#
#       king_squares_attacked  king_moves  king_moves_weighted  \
# 1106               1.153846           1                   39
# 1463               0.875000           0                    0
# 1795               0.000000           0                    0
# 542                0.200000           1                   34
# 1656               0.809524           2                   69
#
#       distance_from_king
# 1106            3.337089
# 1463            3.559085
# 1795            3.504067
# 542             3.326881
# 1656            3.370083
#
# [5 rows x 93 columns]

# %%
y_train.head()
# Out:
# 1106    Russian
# 1463      Other
# 1795      Other
# 542       Rosen
# 1656    Russian
# Name: white_player, dtype: object

# %%
# %matplotlib notebook

pipe = Pipeline([('scaler',StandardScaler()),('pca',PCA(n_components = 3))])
transform = pipe.fit_transform(X)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for label in ['Rosen','Russian','Other']:
    indices = y == label
    ax.scatter(transform[indices][:,0],transform[indices][:,1],transform[indices][:,2],label=label)
ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib inline

# %%
# ('knn',KNeighborsClassifier(n_neighbors = 5))
# ('svc', SVC(kernel = "rbf", C=1))
pipe = Pipeline([('scaler',StandardScaler()),
                 ('pca',PCA(n_components = 20)),
                 ('svc', SVC(kernel = "rbf", C=1))
                ])
pipe.fit(X_train,y_train)

pred = pipe.predict(X_test)
sum(pred==y_test)/len(y_test)
# Out:
# 0.7300771208226221

# %%
import sklearn

guesses = pred
actual = y_test

labels = ['Rosen','Russian','Other']

c_matrix = np.round(sklearn.metrics.confusion_matrix(actual,guesses,labels = labels) / len(y_test),2)

# %%
fig, ax = plt.subplots()
im = ax.imshow(c_matrix)

# We want to show all ticks...
ax.set_xticks(np.arange(len(labels)))
ax.set_yticks(np.arange(len(labels)))
# ... and label them with the respective list entries
ax.set_xticklabels(labels)
ax.set_yticklabels(labels)

# Axes labels
plt.ylabel('Actual')
plt.xlabel('Predicted')

# Loop over data dimensions and create text annotations.
for i in range(len(labels)):
    for j in range(len(labels)):
        text = ax.text(j, i, c_matrix[i, j],
                       ha="center", va="center", color="w")

fig.colorbar(im)
        
ax.set_title("Confusion matrix")
fig.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# I mean, not great because it isn't predicting Rosen as much as you'd hope (you'd want ~25%)
#
# But it's 73% accurate and has the least confusion on Rosen-Russian decisions
#
# Plus, 'Other' is a really broad category
